# %% [markdown]
# ## Portal da Transparencia
# ### Arquivo de Licitações

# %%
# http://www.portaltransparencia.gov.br/download-de-dados/licitacoes/ 
# Arquivo mensal

# %%
import pandas as pd

# %%
import pymysql
import sqlalchemy

# %%
engine = sqlalchemy.create_engine( "mysql+pymysql://glauco:xxxx@192.168.0.4:3306/staging" )

# %% [markdown]
# ### 1 - Arquivo de Licitações

# %%
# Buscar informações das tabelas 
df = pd.read_sql_table("tb_cgu_licitacao",engine)

# %%
df.head()
# Out:
#   num_licitacao  cod_ug cod_modal_compra  \
# 0     000012018  925206                5
# 1     000012018  160012              -99
# 2     000012019  926755              -99
# 3     000012019  927706              -99
# 4     000012019  927760                5
#
#                                        nome_ug                 mod_compral  \
# 0          PMSP - DIR. REG. EDUC. - SÃO MATEUS                      Pregão
# 1       CENTRO DE INSTRUCAO DE GUERRA NA SELVA  Pregão - Registro de Preço
# 2     FUNDAÇÃO CULTURAL DE JOÃO PESSOA FUNJOPE  Pregão - Registro de Preço
# 3  CONSELHO REG DOS TÉCNICOS INDUSTRIAIS DO RN  Pregão - Registro de Preço
# 4   CONSELHO REGIONAL DOS TECNICOS INDUSTRIAIS                      Pregão
#
#         num_processo                                            objecto  \
# 0   6016201800295980  Objeto: Pregão Eletrônico -  Contratação de em...
# 1  64207000554201819  Objeto: Pregão Eletrônico -  Aquisição de alim...
# ...

# %%
df.groupby( ['situacao'] )['cod_ug'].count()
# Out:
# situacao
# Anulação                            20
# Divulgado                          436
# Encerrado                         2199
# Evento de Adiamento Divulgado       16
# Evento de Adiamento Publicado       23
# Evento de Alteração Divulgado       43
# Evento de Alteração Publicado       36
# Evento de Alteração de Resulta      14
# Evento de Anulação Publicado        17
# Evento de Reabertura de Prazo       49
# Evento de Resultado de Julgame     612
# Evento de Retificação Divulgad       3
# Evento de Retificação Publicad      20
# Evento de Revogação Divulgado        3
# Evento de Revogação Publicado       12
# Evento de Suspensão Publicado       48
# Inválido                             2
# Publicado                         1471
# Retificação                         47
# Revogação                           18
# Name: cod_ug, dtype: int64

# %%
df.groupby( ['nom_orgao'] )['cod_ug'].count()
# Out:
# nom_orgao
# Advocacia-Geral da União - Unidades com víncu    13
# Agência Espacial Brasileira                       2
# Agência Nacional de Aviação Civil                 6
# Agência Nacional de Energia Elétrica              2
# Agência Nacional de Mineração                    37
#                                                  ..
# Universidade Federal do Sul da Bahia              3
# Universidade Federal do Sul e Sudeste do Pará     4
# Universidade Federal do Triângulo Mineiro         8
# Universidade Tecnológica Federal do Paraná       29
# Universidade da Integração Internacional da L     2
# Name: cod_ug, Length: 252, dtype: int64

# %% [markdown]
# # 2 - Item das Licitações

# %%
# Buscar informações das tabelas 
df2 = pd.read_sql_table("tb_cgu_licitacao_item",engine)

# %%
df2.head()
# Out:
#   num_licitacao  cod_ug cod_modal_compra  \
# 0     000012018  925206                5
# 1     000012018  160012              -99
# 2     000012018  160012              -99
# 3     000012018  160012              -99
# 4     000012018  160012              -99
#
#                                   nome_ug                 mod_compral  \
# 0     PMSP - DIR. REG. EDUC. - SÃO MATEUS                      Pregão
# 1  CENTRO DE INSTRUCAO DE GUERRA NA SELVA  Pregão - Registro de Preço
# 2  CENTRO DE INSTRUCAO DE GUERRA NA SELVA  Pregão - Registro de Preço
# 3  CENTRO DE INSTRUCAO DE GUERRA NA SELVA  Pregão - Registro de Preço
# 4  CENTRO DE INSTRUCAO DE GUERRA NA SELVA  Pregão - Registro de Preço
#
#         num_processo cod_orgao            nom_orgao   cnpj_vencedor  \
# 0   6016201800295980     95420  ESTADO DE SAO PAULO  55905350000199
# 1  64207000554201819     52121  Comando do Exército  21860768000105
# 2  64207000554201819     52121  Comando do Exército  30771627000107
# ...

# %%
df.groupby( ['mod_compral'] )['cod_ug'].count()
# Out:
# mod_compral
# Concorrência                       1
# Concurso                           1
# Convite                            2
# Dispensa de Licitação           2348
# Inexigibilidade de Licitação     883
# Pregão                           863
# Pregão - Registro de Preço       976
# Tomada de Preços                  15
# Name: cod_ug, dtype: int64

# %% [markdown]
# # 3 - Participantes

# %%
## CNPJ disponivel

# %%
# Buscar informações das tabelas 
df3 = pd.read_sql_table("tb_cgu_licitacao_participante",engine)

# %%
df3.head()
# Out:
#   num_licitacao  cod_ug cod_modal_compra                              nome_ug  \
# 0     000012018  925206                5  PMSP - DIR. REG. EDUC. - SÃO MATEUS
# 1     000012018  925206                5  PMSP - DIR. REG. EDUC. - SÃO MATEUS
# 2     000012018  925206                5  PMSP - DIR. REG. EDUC. - SÃO MATEUS
# 3     000012018  925206                5  PMSP - DIR. REG. EDUC. - SÃO MATEUS
# 4     000012018  925206                5  PMSP - DIR. REG. EDUC. - SÃO MATEUS
#
#   mod_compral      num_processo cod_orgao            nom_orgao  \
# 0      Pregão  6016201800295980     95420  ESTADO DE SAO PAULO
# 1      Pregão  6016201800295980     95420  ESTADO DE SAO PAULO
# 2      Pregão  6016201800295980     95420  ESTADO DE SAO PAULO
# 3      Pregão  6016201800295980     95420  ESTADO DE SAO PAULO
# 4      Pregão  6016201800295980     95420  ESTADO DE SAO PAULO
#
#                  cod_item                                          desc_item  \
# ...

# %%
df3.groupby( ['mod_compral'] )['cod_ug'].count()
# Out:
# mod_compral
# Concorrência                         1
# Concurso                             6
# Convite                              2
# Dispensa de Licitação            12919
# Inexigibilidade de Licitação      4919
# Pregão                           33618
# Pregão - Registro de Preço      217356
# Tomada de Preços                    15
# Name: cod_ug, dtype: int64

# %%
df3.groupby( ['desc_item'] )['cod_ug'].count()
# Out:
# desc_item
# 'ACHOCOLATADO'       313
# 'ARROZ'               47
# 'AVEIA'               29
# 'AZEITE OLIVA'       107
# 'AÇÚCAR'             355
#                     ...
# ÓXIDO DE FERRO         4
# ÓXIDO DE ZINCO         2
# ÓXIDO DE ZIRCÔNIO     21
# ÓXIDO DE ÓSMIO         2
# ÔNIBUS               190
# Name: cod_ug, Length: 4882, dtype: int64
