# %% [markdown]
# ## Portal da Transparencia
# ### Arquivos de Sanções Aplicadas a Empresas

# %%
# http://www.portaltransparencia.gov.br/download-de-dados/
# Arquivo distribuidos peridicamente

# %%
import pandas as pd

# %%
import pymysql
import sqlalchemy

# %%
engine = sqlalchemy.create_engine( "mysql+pymysql://glauco:xxxx@192.168.0.4:3306/staging" )

# %% [markdown]
# ## 1 - Empresas Inidoneas

# %%
# Buscar informações das tabelas 
df = pd.read_sql_table("tb_cgu_sancao_acordo_leniencia",engine)

# %%
df.head()
# Out:
#    id_acordo        cpf_cnpj                                     nome  \
# 0     100001    EXBILFINGER       BILFINGER MASCHINENBAU GMBH & CO KG
# 1     800001  22641641000168  AMBIENTAL ENGENHARIA E CONSULTORIA LTDA
# 2     900001  42150391000170                              BRASKEM S.A
# 3     900002  75609123000123        OURO VERDE LOCACAO E SERVICO S.A.
# 4    1000001  28910529000161           FLEXIBRAS TUBOS FLEXIVEIS LTDA
#
#   razao_social nom_fantasia dat_ini_acordo dat_fim_acordo sit_acordo  \
# 0                14/08/2017     31/12/2019    Em Execução
# 1                27/05/2019     16/10/2019    Em Execução
# 2      BRASKEM   31/05/2019     30/01/2025    Em Execução
# 3                01/04/2019     03/08/2020    Em Execução
# 4                25/06/2019     25/06/2021    Em Execução
#
#                dat_info                                      desc_processo  \
# 0  00190.016403/2015-75  O acordo foi celebrado em 14/08/2017 entre a C...
# ...

# %% [markdown]
# ## 2 - Empresas Punidas

# %%
# Buscar informações das tabelas 
df2 = pd.read_sql_table("tb_cgu_sancao_empresas_punidas",engine)

# %%
df2.head()
# Out:
#   tipo_pessoa        cpf_cnpj  \
# 0           F     34058422807
# 1           J  21504073000190
# 2           J  10699386000125
# 3           J  07486627000143
# 4           J  06940189000189
#
#                                                 nome  \
# 0                              SEVERINO JOSÉ MAFALDO
# 1  CENTRO DE FORMAÇÃO DE CONDUTORES SERRACAR LARA...
# 2  TEC LIGHT INDUSTRIA E COMERCIO DE REATORES EIRELI
# 3                                 C.A.M. CASTILHO ME
# 4              MEC PRESS ENGENHARIA DO BRASIL EIRELI
#
#                                         razao_social          nom_fantasia  \
# 0
# 1  CENTRO DE FORMACAO DE CONDUTORES SERRA-CAR LAR...
# 2  TEC LIGHT INDUSTRIA E COMERCIO DE REATORES EIRELI
# 3                                 C. A. M. CASTILHOS    IMAGENS E NEGOCIOS
# 4                          MEC PRESS ENGENHARIA LTDA  MEC PRESS ENGENHARIA
#
#        num_processo            tipo_sancao dat_inicio_sancao dat_final_sancao  \
# ...

# %% [markdown]
# ## 3 - Entidades Impedidas

# %%
# Buscar informações das tabelas 
df2 = pd.read_sql_table("tb_cgu_sancao_entidade_impedida",engine)

# %%
df.head()
# Out:
#    id_acordo        cpf_cnpj                                     nome  \
# 0     100001    EXBILFINGER       BILFINGER MASCHINENBAU GMBH & CO KG
# 1     800001  22641641000168  AMBIENTAL ENGENHARIA E CONSULTORIA LTDA
# 2     900001  42150391000170                              BRASKEM S.A
# 3     900002  75609123000123        OURO VERDE LOCACAO E SERVICO S.A.
# 4    1000001  28910529000161           FLEXIBRAS TUBOS FLEXIVEIS LTDA
#
#   razao_social nom_fantasia dat_ini_acordo dat_fim_acordo sit_acordo  \
# 0                14/08/2017     31/12/2019    Em Execução
# 1                27/05/2019     16/10/2019    Em Execução
# 2      BRASKEM   31/05/2019     30/01/2025    Em Execução
# 3                01/04/2019     03/08/2020    Em Execução
# 4                25/06/2019     25/06/2021    Em Execução
#
#                dat_info                                      desc_processo  \
# 0  00190.016403/2015-75  O acordo foi celebrado em 14/08/2017 entre a C...
# ...

# %% [markdown]
# ## 4 - Acordo de Leniencia

# %%
df2 = pd.read_sql_table("tb_cgu_sancao_acordo_leniencia",engine)

# %%
df2.head()
# Out:
#    id_acordo        cpf_cnpj                                     nome  \
# 0     100001    EXBILFINGER       BILFINGER MASCHINENBAU GMBH & CO KG
# 1     800001  22641641000168  AMBIENTAL ENGENHARIA E CONSULTORIA LTDA
# 2     900001  42150391000170                              BRASKEM S.A
# 3     900002  75609123000123        OURO VERDE LOCACAO E SERVICO S.A.
# 4    1000001  28910529000161           FLEXIBRAS TUBOS FLEXIVEIS LTDA
#
#   razao_social nom_fantasia dat_ini_acordo dat_fim_acordo sit_acordo  \
# 0                14/08/2017     31/12/2019    Em Execução
# 1                27/05/2019     16/10/2019    Em Execução
# 2      BRASKEM   31/05/2019     30/01/2025    Em Execução
# 3                01/04/2019     03/08/2020    Em Execução
# 4                25/06/2019     25/06/2021    Em Execução
#
#                dat_info                                      desc_processo  \
# 0  00190.016403/2015-75  O acordo foi celebrado em 14/08/2017 entre a C...
# ...
