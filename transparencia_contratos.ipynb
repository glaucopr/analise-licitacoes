# %% [markdown]
# ## Portal da Transparencia
# ### Arquivo de Contratos

# %%
# http://www.portaltransparencia.gov.br/download-de-dados/compras
# Arquivo mensal

# %%
import pandas as pd

# %%
import pymysql
import sqlalchemy

# %%
engine = sqlalchemy.create_engine( "mysql+pymysql://glauco:xxxx@192.168.0.4:3306/staging" )

# %% [markdown]
# ## 1 - Arquivo Compras

# %%
# Buscar informações das tabelas 
df = pd.read_sql_table("tb_cgu_contrato_compras",engine)

# %%
df.head()
# Out:
#    num_contrato                                             objeto  \
# 0         12020  Objeto: Prestação de serviço de limpeza, conse...
# 1        852020  Objeto: Prestação de serviço de coleta, transp...
# 2       3972019  Objeto: Aquisição de material de consumo(Aquis...
# 3       3422019  OBJETO: Execução de serviços/obras para recupe...
# 4        252020        Objeto: Aquisição de 50 suportes para soro.
#
#                                     fundamento_legal  \
# 0                    Fundamento Legal: lei 8666/1993
# 1                 Fundamento Legal: Lei n.º 8.666/93
# 2       Fundamento Legal: Art.61 PU da Lei 8.666/93.
# 3              Fundamento Legal: Lei nº 13.303/2016.
# 4  Fundamento Legal: Lei 8.666/93 e suas alterações.
#
#              cod_modal_compra   situacao  cod_orgal_super  \
# 0                      Pregão  Publicado            22000
# 1                      Pregão  Publicado            26000
# 2  Pregão - Registro de Preço  Publicado            36000
# ...

# %%
df.groupby( ['situacao'] )['cod_ug'].count()
# Out:
# situacao
# Fechado                     301
# Pendente                     36
# Publicado                  2480
# Rescindido                    3
# Rescindido - Publicado       22
# Retificação - Publicado      84
# Name: cod_ug, dtype: int64

# %%
df.groupby( ['cod_modal_compra'] )['cod_ug'].count()
# Out:
# cod_modal_compra
# Concorrência                         30
# Concorrência - Registro de Preço      2
# Concorrência Internacional            1
# Convite                              11
# Dispensa de Licitação               504
# Inexigibilidade de Licitação        282
# Pregão                              705
# Pregão - Registro de Preço          952
# Sem Informação                      331
# Tomada de Preços                    108
# Name: cod_ug, dtype: int64

# %% [markdown]
# ## 2 - Item Compras

# %%
# Buscar informações das tabelas 
df2 = pd.read_sql_table("tb_cgu_contrato_item_compra",engine)

# %%
df2.head()
# Out:
#   cod_orgao                        nom_orgao  cod_ug  \
# 0     52121              Comando do Exército  160100
# 1     30108  Departamento de Polícia Federal  200366
# 2     30108  Departamento de Polícia Federal  200366
# 3     30108  Departamento de Polícia Federal  200366
# 4     30108  Departamento de Polícia Federal  200366
#
#                                           nom_ug num_contrato  \
# 0   COMANDO DA 3A BDA DE INFANTARIA   MOTORIZADA        12018
# 1  DELEGACIA DE POLICIA FEDERAL EM FOZ DO IGUAçU        12019
# 2  DELEGACIA DE POLICIA FEDERAL EM FOZ DO IGUAçU        12019
# 3  DELEGACIA DE POLICIA FEDERAL EM FOZ DO IGUAçU        12019
# 4  DELEGACIA DE POLICIA FEDERAL EM FOZ DO IGUAçU        12019
#
#           cod_item_compra                                   desc_item_compra  \
# 0  1601000700004201800001  ANALISE CLINICA, ANATOMIA PATOLOGICA E CITOPAT...
# 1                       0  Informação protegida por sigilo nos termos da ...
# ...

# %%
df.groupby( ['nom_orgao'] )['cod_ug'].count()
# Out:
# nom_orgao
# Advocacia-Geral da União - Unidades com víncu    10
# Agência Nacional de Aviação Civil                 4
# Agência Nacional de Energia Elétrica              3
# Agência Nacional de Mineração                     9
# Agência Nacional de Saúde Suplementar             3
#                                                  ..
# Universidade Federal do Sul e Sudeste do Pará     3
# Universidade Federal do Triângulo Mineiro         3
# Universidade Tecnológica Federal do Paraná       12
# Universidade da Integração Internacional da L     3
# VALEC Engenharia, Construções e Ferrovias S.A     1
# Name: cod_ug, Length: 201, dtype: int64

# %% [markdown]
# ## 3 - Termo Aditivo

# %%
# Buscar informações das tabelas 
df2 = pd.read_sql_table("tb_cgu_contrato_termo_aditivo",engine)

# %%
df.head()
# Out:
#    num_contrato                                             objeto  \
# 0         12020  Objeto: Prestação de serviço de limpeza, conse...
# 1        852020  Objeto: Prestação de serviço de coleta, transp...
# 2       3972019  Objeto: Aquisição de material de consumo(Aquis...
# 3       3422019  OBJETO: Execução de serviços/obras para recupe...
# 4        252020        Objeto: Aquisição de 50 suportes para soro.
#
#                                     fundamento_legal  \
# 0                    Fundamento Legal: lei 8666/1993
# 1                 Fundamento Legal: Lei n.º 8.666/93
# 2       Fundamento Legal: Art.61 PU da Lei 8.666/93.
# 3              Fundamento Legal: Lei nº 13.303/2016.
# 4  Fundamento Legal: Lei 8.666/93 e suas alterações.
#
#              cod_modal_compra   situacao  cod_orgal_super  \
# 0                      Pregão  Publicado            22000
# 1                      Pregão  Publicado            26000
# 2  Pregão - Registro de Preço  Publicado            36000
# ...

# %%
df.groupby( ['cod_modal_compra'] )['cod_ug'].count()
# Out:
# cod_modal_compra
# Concorrência                         30
# Concorrência - Registro de Preço      2
# Concorrência Internacional            1
# Convite                              11
# Dispensa de Licitação               504
# Inexigibilidade de Licitação        282
# Pregão                              705
# Pregão - Registro de Preço          952
# Sem Informação                      331
# Tomada de Preços                    108
# Name: cod_ug, dtype: int64
